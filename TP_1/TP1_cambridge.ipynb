# %%
import numpy as np
import pandas as pd

# %%
# Fonction pour calculer les valeurs manquantes par colonne
def missing_values(df):
        # Total des valeurs manquantes
        mis_val = df.isnull().sum()

        # Pourcentage des valeurs manquantes
        mis_val_percent = 100 * mis_val / len(df)

        # Faites un tableau avec les résultats
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

        # Renomer les colonnes
        mis_val_table = mis_val_table.rename(columns = {0 : 'Valeurs manquantes', 1 : '% du Total des valeurs'})

        # Trier le tableau par pourcentage de décroissant manquant
        mis_val_table = mis_val_table[mis_val_table.iloc[:,1] != 0].sort_values('% du Total des valeurs', ascending=False).round(1)

        # Imprimer des informations récapitulatives
        print ("Votre dataframe sélectionné a " + str(df.shape[1]) + " colonnes.")
        print ("Il y a " + str(mis_val_table.shape[0]) +" colonnes qui ont des valeurs manquantes.")

       # Renvoie le dataframe avec les informations manquantes
        return mis_val_table

# %%
df = pd.read_csv('cambridge.csv')
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20191126082128   2019-11-26
# 1  11169  https://www.airbnb.com/rooms/11169  20191126082128   2019-11-26
# 2  11945  https://www.airbnb.com/rooms/11945  20191126082128   2019-11-26
# 3  19581  https://www.airbnb.com/rooms/19581  20191126082128   2019-11-26
# 4  22006  https://www.airbnb.com/rooms/22006  20191126082128   2019-11-26
#
#                                                 name  \
# 0  SunsplashedSerenity near Harvard $1300/wk flex...
# 1    Lovely Studio Room: Thu-Mons Near Universities!
# 2                   Near Harvard: Safe & Lovely Room
# 3                           Furnished suite, Windsor
# 4                   B & B near Harvard's Quad Houses
#
#                                              summary  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...
# 1  Large sunny room which comfortably fits a coup...
# 2  Room next to kitchen and living room in wonder...
# 3  Welcome to Area IV! We are located, convenient...
# 4  Two comfortable guest rooms in quiet, tree-fil...
#
#                                                space  \
# 0  An elegant, sun-splashed, 2+ bedroom apartment...
# 1  We have a peaceful, large, sunny room w/ attac...
# 2  Quiet peaceful room w/shared marble bath, wifi...
# 3  Furnished suite at the Windsor Inn, Cambridge....
# 4  Comfortable, convenient B&B at the north end o...
#
#                                          description experiences_offered  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...                none
# 1  Large sunny room which comfortably fits a coup...                none
# 2  Room next to kitchen and living room in wonder...                none
# 3  Welcome to Area IV! We are located, convenient...                none
# 4  Two comfortable guest rooms in quiet, tree-fil...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Huron Village is known for its charm.  We have...  ...                f
# 1  The neighborhood is quiet and friendly and our...  ...                f
# 2  Amazing neighborhood: Quiet yet close walk to ...  ...                f
# 3                                                NaN  ...                f
# 4  We're in a beautiful neighborhood, with nearby...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             t                                t
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               4
# 2                               4
# 3                               3
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            3
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.26
# 1                                            0               1.22
# 2                                            0               0.27
# 3                                            0               0.05
# 4                                            0               0.89
#
# [5 rows x 106 columns]

# %%
df.shape
# Out:
# (1277, 106)

# %%
df.describe(include="all")
# Out:
#                   id                        listing_url     scrape_id  \
# count   1.277000e+03                               1277  1.277000e+03
# unique           NaN                               1277           NaN
# top              NaN  https://www.airbnb.com/rooms/8521           NaN
# freq             NaN                                  1           NaN
# mean    2.072702e+07                                NaN  2.019113e+13
# std     1.203935e+07                                NaN  0.000000e+00
# min     8.521000e+03                                NaN  2.019113e+13
# 25%     1.036623e+07                                NaN  2.019113e+13
# 50%     2.120450e+07                                NaN  2.019113e+13
# 75%     3.126584e+07                                NaN  2.019113e+13
# max     4.032730e+07                                NaN  2.019113e+13
#
#        last_scraped                                name  \
# count          1277                                1277
# unique            1                                1254
# top      2019-11-26  Lux 1 Bedroom Cambridge Apt by MIT
# freq           1277                                   5
# mean            NaN                                 NaN
# std             NaN                                 NaN
# min             NaN                                 NaN
# 25%             NaN                                 NaN
# 50%             NaN                                 NaN
# 75%             NaN                                 NaN
# max             NaN                                 NaN
#
#                                                   summary  \
# count                                                1248
# unique                                               1062
# top     Clean and comfortable room,8 min.walking dista...
# freq                                                   14
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     space  \
# count                                                1014
# unique                                                869
# top     Room equipped with mini-fridge, microwave, des...
# freq                                                   10
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               description experiences_offered  \
# count                                                1267                1277
# unique                                               1158                   1
# top     Located amidst leading academic institutions l...                none
# freq                                                    9                1277
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#                                     neighborhood_overview  ...  \
# count                                                 938  ...
# unique                                                680  ...
# top     This furnished apartment is situated on Kendal...  ...
# freq                                                   21  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#        instant_bookable is_business_travel_ready          cancellation_policy  \
# count              1277                     1277                         1277
# unique                2                        1                            5
# top                   f                        f  strict_14_with_grace_period
# freq                729                     1277                          624
# mean                NaN                      NaN                          NaN
# std                 NaN                      NaN                          NaN
# min                 NaN                      NaN                          NaN
# 25%                 NaN                      NaN                          NaN
# 50%                 NaN                      NaN                          NaN
# 75%                 NaN                      NaN                          NaN
# max                 NaN                      NaN                          NaN
#
#        require_guest_profile_picture require_guest_phone_verification  \
# count                           1277                             1277
# unique                             2                                2
# top                                f                                f
# freq                            1248                             1208
# mean                             NaN                              NaN
# std                              NaN                              NaN
# min                              NaN                              NaN
# 25%                              NaN                              NaN
# 50%                              NaN                              NaN
# 75%                              NaN                              NaN
# max                              NaN                              NaN
#
#         calculated_host_listings_count  \
# count                      1277.000000
# unique                             NaN
# top                                NaN
# freq                               NaN
# mean                          6.401723
# std                           9.336571
# min                           1.000000
# 25%                           1.000000
# 50%                           3.000000
# 75%                           6.000000
# max                          41.000000
#
#         calculated_host_listings_count_entire_homes  \
# count                                   1277.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                       3.498825
# std                                        6.861097
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                       35.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   1277.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                       2.886453
# std                                        6.385631
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        3.000000
# max                                       33.000000
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                   1277.000000        1099.000000
# unique                                          NaN                NaN
# top                                             NaN                NaN
# freq                                            NaN                NaN
# mean                                       0.016445           2.053130
# std                                        0.127228           2.174205
# min                                        0.000000           0.020000
# 25%                                        0.000000           0.390000
# 50%                                        0.000000           1.130000
# 75%                                        0.000000           3.195000
# max                                        1.000000          10.920000
#
# [11 rows x 106 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
missing_values(df)
# Out:
# Votre dataframe sélectionné a 106 colonnes.
# Il y a 47 colonnes qui ont des valeurs manquantes.
#                               Valeurs manquantes  % du Total des valeurs
# medium_url                                  1277                   100.0
# thumbnail_url                               1277                   100.0
# host_acceptance_rate                        1277                   100.0
# neighbourhood_group_cleansed                1277                   100.0
# xl_picture_url                              1277                   100.0
# square_feet                                 1268                    99.3
# license                                     1182                    92.6
# monthly_price                               1120                    87.7
# weekly_price                                1112                    87.1
# notes                                        623                    48.8
# access                                       506                    39.6
# interaction                                  435                    34.1
# host_about                                   434                    34.0
# house_rules                                  430                    33.7
# transit                                      339                    26.5
# neighborhood_overview                        339                    26.5
# security_deposit                             328                    25.7
# space                                        263                    20.6
# review_scores_cleanliness                    190                    14.9
# review_scores_accuracy                       190                    14.9
# review_scores_value                          190                    14.9
# review_scores_checkin                        190                    14.9
# review_scores_communication                  190                    14.9
# review_scores_location                       190                    14.9
# review_scores_rating                         190                    14.9
# host_response_time                           184                    14.4
# host_response_rate                           184                    14.4
# first_review                                 178                    13.9
# last_review                                  178                    13.9
# reviews_per_month                            178                    13.9
# cleaning_fee                                 141                    11.0
# host_neighbourhood                            72                     5.6
# summary                                       29                     2.3
# zipcode                                       13                     1.0
# description                                   10                     0.8
# market                                         5                     0.4
# host_location                                  5                     0.4
# beds                                           2                     0.2
# host_identity_verified                         1                     0.1
# host_has_profile_pic                           1                     0.1
# host_total_listings_count                      1                     0.1
# host_picture_url                               1                     0.1
# host_thumbnail_url                             1                     0.1
# host_is_superhost                              1                     0.1
# host_since                                     1                     0.1
# host_name                                      1                     0.1
# host_listings_count                            1                     0.1

# %% [markdown]
# Supprimer les colonnes qui ont un pourcentage de valeurs manquantes supérieur à 80% est une pratique courante en prétraitement des données pour les raisons suivantes :
#
# Concentration sur les données significatives : Les colonnes avec plus de 80% de valeurs manquantes contiennent très peu d'informations utilisables. En les supprimant, on se concentre sur les variables qui ont plus de chances de fournir des insights pertinents et d'améliorer la qualité des analyses. Cela permet d'éviter de baser les analyses sur des données sporadiques qui pourraient introduire du bruit plutôt que des informations valables.

# %%
df.drop(['medium_url','thumbnail_url','host_acceptance_rate','neighbourhood_group_cleansed','xl_picture_url',
         'square_feet','license','monthly_price','weekly_price'],axis=1,inplace=True)

# %%
df['experiences_offered'].value_counts()
# Out:
# none    1277
# Name: experiences_offered, dtype: int64

# %%
df.drop(['experiences_offered'],axis=1,inplace=True)

# %% [markdown]
# ## URLs et Identifiants
# Ces colonnes contiennent des liens vers des images ou des pages web. Elles sont spécifiques à chaque listing ou hôte et n'apportent pas de valeur analytique quantitative ou catégorielle pertinente.

# %%
df.drop(['id','listing_url','scrape_id','last_scraped',  'picture_url',
 'host_id','host_url',  'host_thumbnail_url','host_picture_url',],axis=1,inplace=True)

# %% [markdown]
# la suppression des colonnes name, summary, et host_name avec la commande data.drop(['name', 'summary', 'host_name'], axis=1, inplace=True) dans un DataFrame pandas peut être justifiée par des raisons de confidentialité et d'anonymisation, la réduction de la dimensionnalité du dataset, la pertinence des données pour l'analyse prévue, et le nettoyage des données. Cette opération aide à simplifier le jeu de données, à accélérer le traitement, et à se concentrer sur les variables qui sont les plus utiles pour atteindre les objectifs d'analyse.

# %%
df.drop(['name', 'summary' , 'host_name'],axis=1,inplace=True)

# %% [markdown]
# #### Explication pour la cellule ci-dessous
#
# Ce code extrait les colonnes numériques d'un DataFrame df, calcule la matrice de corrélation entre ces colonnes, et identifie les paires de colonnes qui sont fortement corrélées (avec une corrélation absolue supérieure à un seuil fixé, ici 0.8). Il stocke ensuite ces paires et leurs coefficients de corrélation dans un dictionnaire high_corr_pairs. Cette approche est utile pour détecter les relations linéaires fortes entre les variables, ce qui peut être important pour éviter la multicollinéarité dans les modèles de régression ou pour simplifier un ensemble de données en éliminant des variables redondantes.

# %%
# Get numerics data
dfNumeric = df.select_dtypes(include=[np.number])
# Calculate the correlation matrix
correlation_matrix = dfNumeric.corr()

# Find pairs of highly correlated columns
high_corr_pairs = {}
threshold = 0.8  # Set a threshold for strong correlation

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            col_name1 = correlation_matrix.columns[i]
            col_name2 = correlation_matrix.columns[j]
            high_corr_pairs[(col_name1, col_name2)] = correlation_matrix.iloc[i, j]

print(high_corr_pairs)
# Out:
# {('host_total_listings_count', 'host_listings_count'): 1.0, ('beds', 'accommodates'): 0.8291525892481777, ('minimum_minimum_nights', 'minimum_nights'): 0.9708772639145603, ('maximum_minimum_nights', 'minimum_nights'): 0.9543335564024591, ('maximum_minimum_nights', 'minimum_minimum_nights'): 0.9250109169045296, ('minimum_maximum_nights', 'maximum_nights'): 0.9620952000715794, ('maximum_maximum_nights', 'maximum_nights'): 0.9622513119420726, ('maximum_maximum_nights', 'minimum_maximum_nights'): 0.9998510029639561, ('minimum_nights_avg_ntm', 'minimum_nights'): 0.9911092874658228, ('minimum_nights_avg_ntm', 'minimum_minimum_nights'): 0.9670544844626342, ('minimum_nights_avg_ntm', 'maximum_minimum_nights'): 0.982504731269963, ('maximum_nights_avg_ntm', 'maximum_nights'): 0.9622512829109207, ('maximum_nights_avg_ntm', 'minimum_maximum_nights'): 0.9998516646922198, ('maximum_nights_avg_ntm', 'maximum_maximum_nights'): 0.9999999992635886, ('availability_60', 'availability_30'): 0.8952876278396935, ('availability_90', 'availability_60'): 0.9629971671737217, ('reviews_per_month', 'number_of_reviews_ltm'): 0.8832003055228741}

# %%
# on supprime les colonnes qui sont fortement corrélées
df.drop(['host_listings_count','accommodates','maximum_minimum_nights','maximum_maximum_nights',
           'minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_60','availability_90',
           'calculated_host_listings_count','calculated_host_listings_count_entire_homes','number_of_reviews_ltm',
           'minimum_minimum_nights','minimum_maximum_nights'],axis=1,inplace=True)

# %% [markdown]
# ## Informations Géographiques Redondantes :
# on laisse latitude et longitude, et on supprime d'autres informations géographiques comme city, country, country_code, neighbourhood, neighbourhood_cleansed, smart_location, state, et street car peuvent être redondantes

# %%
geo_columns_to_drop = [
    'street', 'neighbourhood', 'neighbourhood_cleansed',
    'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country',
    'is_location_exact','host_neighbourhood'
]
df.drop(geo_columns_to_drop ,axis=1,inplace=True)

# %%
# Colonnes à supprimer avec les raisons pour lesquelles elles sont considérées comme inutiles
columns_to_remove = [
    'calendar_last_scraped', # La date de la dernière extraction ne change pas l'analyse des propriétés
    'calendar_updated', # Informations sur la dernière mise à jour du calendrier, pas critique pour la plupart des analyses
    'has_availability', # Peut être constant et non informatif pour toutes les annonces
    'is_business_travel_ready', # Spécifique à un type de voyageur, peut ne pas être nécessaire pour des analyses générales
    'requires_license', # Informations réglementaires qui ne sont pas critiques pour l'analyse de la propriété
    'host_total_listings_count', # Potentiellement redondante si des informations plus spécifiques sur le type de listing sont disponibles
    'jurisdiction_names', # Détails réglementaires spécifiques qui peuvent ne pas être nécessaires
    'require_guest_phone_verification', # Politique de réservation de l'hôte, pas essentielle pour une analyse de propriété
    'require_guest_profile_picture' ,# Politique de réservation de l'hôte, pas essentielle pour une analyse de propriété
    'host_about' , # elle contient des descriptions textuelles de l'hôte, non essentielles pour l'analyse quantitative.
    'notes'# elle contient souvent des informations incohérentes et spécifiques au listing, peu utiles pour l'analyse globale.

]

# Supprimer les colonnes inutiles du DataFrame
df.drop(columns=columns_to_remove,axis=1,inplace=True)

# %%
list(sorted(df.columns))
# Out:
# ['access',
#  'amenities',
#  'availability_30',
#  'availability_365',
#  'bathrooms',
#  'bed_type',
#  'bedrooms',
#  'beds',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'cancellation_policy',
#  'cleaning_fee',
#  'description',
#  'extra_people',
#  'first_review',
#  'guests_included',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_is_superhost',
#  'host_location',
#  'host_response_rate',
#  'host_response_time',
#  'host_since',
#  'host_verifications',
#  'house_rules',
#  'instant_bookable',
#  'interaction',
#  'last_review',
#  'latitude',
#  'longitude',
#  'maximum_nights',
#  'minimum_nights',
#  'neighborhood_overview',
#  'number_of_reviews',
#  'price',
#  'property_type',
#  'review_scores_accuracy',
#  'review_scores_checkin',
#  'review_scores_cleanliness',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_rating',
#  'review_scores_value',
#  'reviews_per_month',
#  'room_type',
#  'security_deposit',
#  'space',
#  'transit']

# %%
df.shape
# Out:
# (1277, 48)

# %%
missing_values(df)
# Out:
# Votre dataframe sélectionné a 48 colonnes.
# Il y a 27 colonnes qui ont des valeurs manquantes.
#                              Valeurs manquantes  % du Total des valeurs
# access                                      506                    39.6
# interaction                                 435                    34.1
# house_rules                                 430                    33.7
# neighborhood_overview                       339                    26.5
# transit                                     339                    26.5
# security_deposit                            328                    25.7
# space                                       263                    20.6
# review_scores_communication                 190                    14.9
# review_scores_accuracy                      190                    14.9
# review_scores_cleanliness                   190                    14.9
# review_scores_checkin                       190                    14.9
# review_scores_location                      190                    14.9
# review_scores_value                         190                    14.9
# review_scores_rating                        190                    14.9
# host_response_rate                          184                    14.4
# host_response_time                          184                    14.4
# last_review                                 178                    13.9
# reviews_per_month                           178                    13.9
# first_review                                178                    13.9
# cleaning_fee                                141                    11.0
# description                                  10                     0.8
# host_location                                 5                     0.4
# beds                                          2                     0.2
# host_has_profile_pic                          1                     0.1
# host_is_superhost                             1                     0.1
# host_since                                    1                     0.1
# host_identity_verified                        1                     0.1

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Variables textuelles)
# Variables textuelles remplacées par "Information non disponible" : Cela maintient la clarté des données en indiquant explicitement l'absence d'information, plutôt que de laisser un vide qui pourrait être interprété de manière erronée.

# %%
# 1. Variables textuelles: Remplacer par "Information non disponible"
text_vars_with_missing = ['access', 'transit', 'interaction', 'neighborhood_overview', 'house_rules', 'space']
df[text_vars_with_missing] = df[text_vars_with_missing].fillna("Information non disponible")

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Variables numériques)
# on utilise la médiane pour remplir les valeurs manquantes dans les données numériques pour les raisons suivantes :
#
# Robustesse aux valeurs extrêmes : La médiane est moins affectée par les valeurs aberrantes que la moyenne.
# Adaptée aux distributions non normales : Elle offre une meilleure mesure de tendance centrale pour les données qui ne sont pas distribuées normalement.
# Convient aux scores catégoriels ordinaux : Pour des données comme les scores de review, la médiane peut mieux refléter l'évaluation typique.
# Simplicité et interprétabilité : C'est une méthode facile à comprendre et à appliquer.
# Préservation de la distribution des données : Utiliser la médiane aide à maintenir la distribution originale des données.

# %%
# 2. Variables numériques (Scores de review): Utiliser la médiane
review_score_vars = ['review_scores_checkin', 'review_scores_location', 'review_scores_value',
                     'review_scores_accuracy', 'review_scores_cleanliness',
                     'review_scores_communication', 'review_scores_rating']
for var in review_score_vars:
    df[var] = df[var].fillna(df[var].median())

# 3. Autres variables numériques: Utiliser la médiane
other_numerical_vars_with_missing = ['beds']
for var in other_numerical_vars_with_missing:
    df[var] = df[var].fillna(df[var].median())

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Variables de review spécifiques)
# reviews_per_month rempli avec 0 : Assigne une valeur neutre aux listings sans reviews, permettant une analyse cohérente sans supposer de l'activité là où il n'y en a pas.

# %%
# 4. Variables de review spécifiques (Traitement spécial pour `reviews_per_month`)
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Variables catégorielles/booléennes)
# Variables catégorielles/booléennes remplacées par le mode : Utilise la valeur la plus fréquente pour maintenir la cohérence des caractéristiques générales du dataset, en supposant que la valeur la plus commune est la plus probable en cas d'information manquante.

# %%
# 5. Variables catégorielles/booléennes: Remplacer par le mode
categorical_bool_vars_with_missing = ['host_has_profile_pic', 'host_identity_verified', 'host_is_superhost', 'host_response_time']
for var in categorical_bool_vars_with_missing:
    df[var] = df[var].fillna(df[var].mode()[0])

# %% [markdown]
# #### Explication pour la cellule ci-dessous (security_deposit)
# security_deposit, cleaning_fee remplacés par 0 : Traite l'absence de frais comme l'indication qu'aucun frais n'est requis, aligné sur une interprétation conservatrice des coûts.

# %%
# 6. `security_deposit`, `cleaning_fee`: Remplacer les valeurs manquantes par zéro
df['security_deposit'] = df['security_deposit'].fillna(0)
df['cleaning_fee'] = df['cleaning_fee'].fillna(0)

# %% [markdown]
# #### Explication pour la cellule ci-dessous (description et host_location)
# Traitement spécial pour description et host_location : Assure que toutes les listings ont des informations de base, même standardisées, pour soutenir des analyses textuelles ou géographiques minimales.

# %%
# 7. `description`, `host_location`: Traitement spécial pour la description et la localisation de l'hôte
df['description'] = df['description'].fillna("Information non disponible")
df['host_location'] = df['host_location'].fillna(df['host_location'].mode()[0])

# %%
# Remplacer 'first_review' et 'last_review' par "non disponible"
df['first_review'].fillna("non disponible", inplace=True)
df['last_review'].fillna("non disponible", inplace=True)

# %% [markdown]
# #### Explication pour la cellule ci-dessous (host_response_rate)
# Conversion de 'host_response_rate' en numérique et remplacement des manquants par la médiane : Fournit une estimation raisonnable de la tendance centrale pour cette variable, permettant une analyse quantitative tout en minimisant l'impact des extrêmes.
#
# Suppression des lignes où host_since est manquant : Élimine les listings avec des informations critiques manquantes sur l'hôte, présumant que l'ancienneté de l'hôte est essentielle pour l'analyse.

# %%
# Étape 1: Conversion de 'host_response_rate' en valeurs numériques
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '').astype(float)

# Étape 2: Calcul de la médiane pour 'host_response_rate'
host_response_rate_median = df['host_response_rate'].median()

# Étape 3: Remplacement des valeurs manquantes par la médiane
df['host_response_rate'].fillna(host_response_rate_median, inplace=True)

# Supposer que la suppression des lignes où 'host_since' est manquant est acceptable pour votre analyse :
df.dropna(subset=['host_since'], inplace=True)

# %%
missing_values(df)
# Out:
# Votre dataframe sélectionné a 48 colonnes.
# Il y a 0 colonnes qui ont des valeurs manquantes.
# Empty DataFrame
# Columns: [Valeurs manquantes, % du Total des valeurs]
# Index: []

# %%
df.dtypes
# Out:
# space                                            object
# description                                      object
# neighborhood_overview                            object
# transit                                          object
# access                                           object
# interaction                                      object
# house_rules                                      object
# host_since                                       object
# host_location                                    object
# host_response_time                               object
# host_response_rate                              float64
# host_is_superhost                                object
# host_verifications                               object
# host_has_profile_pic                             object
# host_identity_verified                           object
# latitude                                        float64
# longitude                                       float64
# property_type                                    object
# room_type                                        object
# bathrooms                                       float64
# bedrooms                                          int64
# beds                                            float64
# bed_type                                         object
# amenities                                        object
# price                                            object
# security_deposit                                 object
# cleaning_fee                                     object
# guests_included                                   int64
# extra_people                                     object
# minimum_nights                                    int64
# maximum_nights                                    int64
# availability_30                                   int64
# availability_365                                  int64
# number_of_reviews                                 int64
# first_review                                     object
# last_review                                      object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# instant_bookable                                 object
# cancellation_policy                              object
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# dtype: object

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Conversion des dates et Conversion des variables monétaires)
# Conversion des dates et des variables monétaires : Normalise les formats pour permettre des analyses temporelles et financières précises.

# %%
# Conversion des dates
df['first_review'] = pd.to_datetime(df['first_review'], errors='coerce')
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')

# %%
# Conversion des variables monétaires
monetary_columns = ['price', 'security_deposit', 'cleaning_fee', 'extra_people']
for col in monetary_columns:
    df[col] = df[col].str.replace('[\$,]', '', regex=True).astype(float)

# %% [markdown]
# #### Explication pour la cellule ci-dessous (Encodage des variables)
# Encodage des variables binaires en 0/1 : Simplifie l'analyse en convertissant les indicateurs textuels en valeurs numériques binaires, facilitant les comparaisons et les calculs statistiques.

# %%
# Encoder les variables binaires 't'/'f' en 0/1
binary_columns = ['host_has_profile_pic', 'host_identity_verified', 'host_is_superhost', 'instant_bookable']

# Boucle sur les colonnes binaires pour les encoder
for col in binary_columns:
    df[col] = df[col].map({'f': 0, 't': 1}).astype(int)

# %%
df.dtypes
# Out:
# space                                                   object
# description                                             object
# neighborhood_overview                                   object
# transit                                                 object
# access                                                  object
# interaction                                             object
# house_rules                                             object
# host_since                                      datetime64[ns]
# host_location                                           object
# host_response_time                                      object
# host_response_rate                                     float64
# host_is_superhost                                        int64
# host_verifications                                      object
# host_has_profile_pic                                     int64
# host_identity_verified                                   int64
# latitude                                               float64
# longitude                                              float64
# property_type                                           object
# room_type                                               object
# bathrooms                                              float64
# bedrooms                                                 int64
# beds                                                   float64
# bed_type                                                object
# amenities                                               object
# price                                                  float64
# security_deposit                                       float64
# cleaning_fee                                           float64
# guests_included                                          int64
# extra_people                                           float64
# minimum_nights                                           int64
# maximum_nights                                           int64
# availability_30                                          int64
# availability_365                                         int64
# number_of_reviews                                        int64
# first_review                                    datetime64[ns]
# last_review                                     datetime64[ns]
# review_scores_rating                                   float64
# review_scores_accuracy                                 float64
# review_scores_cleanliness                              float64
# review_scores_checkin                                  float64
# review_scores_communication                            float64
# review_scores_location                                 float64
# review_scores_value                                    float64
# instant_bookable                                         int64
# cancellation_policy                                     object
# calculated_host_listings_count_private_rooms             int64
# calculated_host_listings_count_shared_rooms              int64
# reviews_per_month                                      float64
# dtype: object
